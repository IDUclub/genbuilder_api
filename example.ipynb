# %% [markdown]
# Сначала импортируем классы и инциализируем их (в апи это происходит в dependencies)

# %%
import os
import geopandas as gpd
import pandas as pd

os.environ["APP_ENV"] = 'development'

from iduconfig import Config

from app.logic.logger_setup import setup_logger

from app.api.urbandb_api_gateway import UrbanDBAPI
from app.api.genbuilder_gateway import GenbuilderInferenceAPI

from app.logic.postprocessing.generation_params import GenParams, ParamsProvider
from app.logic.building_generation.building_capacity_optimizer import CapacityOptimizer
from app.logic.building_generation.maximum_inscribed_rectangle import MIR
from app.logic.building_generation.segments import SegmentsAllocator
from app.logic.building_generation.plots import PlotsGenerator
from app.logic.building_generation.buildings import ResidentialBuildingsGenerator
from app.logic.building_generation.residential_generator import ResidentialGenBuilder
from app.logic.building_generation.residential_service_generation import ResidentialServiceGenerator
from app.logic.building_generation.building_params import (
    BuildingGenParams,
    BuildingParamsProvider,
    PARAMS_BY_TYPE
)

config = Config()
setup_logger(config, log_level="INFO")

urban_db_api = UrbanDBAPI(config)

generation_parameters = GenParams()
params_provider = ParamsProvider(generation_parameters)

buildings_params = BuildingGenParams(params_by_type=PARAMS_BY_TYPE)
buildings_params_provider = BuildingParamsProvider(base=buildings_params)

# %% [markdown]
# Далее используем уже инициализированные классы (из logic.building_generator.residential_generator)

# %%
building_capacity_optimizer = CapacityOptimizer(buildings_params_provider)
max_rectangle_finder = MIR()
segments_allocator = SegmentsAllocator(building_capacity_optimizer, buildings_params_provider)
plots_generator = PlotsGenerator(params_provider, buildings_params_provider)
residential_buildings_generator = ResidentialBuildingsGenerator()
residential_generator = ResidentialGenBuilder(building_capacity_optimizer, max_rectangle_finder, 
                    segments_allocator, plots_generator, residential_buildings_generator, params_provider)
residential_service_generator = ResidentialServiceGenerator(params_provider)

# %% [markdown]
# Здесь происходит имитиация передачи входных параметров - полигонов кварталов, целевой жилой площади по всему проекту, типу этажности и целевому сценарию плотности.
#
# Типы этажности (задаются в building_params):
# - private: ИЖС
# - low: 2-4 этажа МКД
# - medium: 5-8 этажей МКД
# - high: 9-16 этажей МКД
# - extreme: 16+ этажей МКД
#
# Сценарии плотности рассчитываются по FAR (суммарная площадь всех этажей здания / площадь участка) для каждого участка.
#
# Сценарии (логика выбора в building_capacity_optimizer.pick_indices):
# - min: максимальная площадь участка, минимальная здания
# - mean: средние значения из допустимых
# - max: минимальная площадь участка, максимальная здания

# %%
blocks = gpd.read_file('zones.geojson')
residential_blocks = blocks[blocks['zone'] == 'residential']
residential_la_target = 10000
default_floors_group = 'medium'
density_scenario = 'min'

# %% [markdown]
# Целевая жилая площадь распределяется по кварталам соразмерно их площади, категория этажности может быть задана отдельно в параметрах входных кварталов, если нет - используется дефолтная.

# %%
residential_blocks["la_target"] = (
    residential_la_target
    * residential_blocks.geometry.area
    / residential_blocks.geometry.area.sum()
)
residential_blocks["floors_group"] = residential_blocks.get("floors_group")
residential_blocks["floors_group"] = residential_blocks["floors_group"].fillna(
    default_floors_group
)
residential_blocks.head(3)
# Out:
#    zone_id         zone floors_group    la_target  \
# 0        1  residential       medium  2385.906444
# 1        2  residential       medium  4916.048384
# 2        3  residential      private  2698.045172
#
#                                             geometry
# 0  POLYGON ((359002.284 6648270.471, 359136.097 6...
# 1  POLYGON ((358808.367 6648679.85, 358993.211 66...
# 2  POLYGON ((359332.282 6648424.696, 359502.384 6...

# %% [markdown]
# В классе CapacityOptimizer предварительно рассчитывается то, сколько зданий требуется уместить в квартал, и сколько возможно.
#
# В начале используются параметры зданий и участков, соответствующие исходному сценарию плотности и типу этажности.
#
# building_need: la_target / living_area
#
# building_capacity: plot_side / block perimeter
#
# Далее, пока building_need < building_capacity, параметры изменяются в сторону увеличения плотности с приоритетом расположения участков по длинной стороне квартала.
#
# Итоговые параметры зданий и участков сохраняются в атрибуты кварталов.

# %%
residential_blocks = building_capacity_optimizer.compute_blocks_for_gdf(
    residential_blocks, density_scenario
)
residential_blocks.head(3)
# Out:
#    zone_id         zone floors_group    la_target  \
# 0        1  residential       medium  2385.906444
# 1        2  residential       medium  4916.048384
# 2        3  residential      private  2698.045172
#
#                                             geometry  building_need  \
# 0  POLYGON ((359002.284 6648270.471, 359136.097 6...            2.0
# 1  POLYGON ((358808.367 6648679.85, 358993.211 66...            5.0
# 2  POLYGON ((359332.282 6648424.696, 359502.384 6...           65.0
#
#    building_capacity  buildings_count  plot_front  plot_depth  ...  \
# 0                NaN              2.0       120.0        50.0  ...
# 1                NaN              5.0       120.0        50.0  ...
# 2                NaN             65.0        40.0        22.5  ...
#
#    building_length  building_width  floors_count  living_per_building  \
# 0             40.0            12.0           5.0               1200.0
# 1             40.0            12.0           5.0               1200.0
# 2              8.0             8.0           1.0                 41.6
#
#    total_living_area      la_diff  la_ratio  far_initial  far_final  far_diff
# 0             2400.0    14.093556  1.005907     0.400000        NaN       NaN
# 1             6000.0  1083.951616  1.220492     0.400000        NaN       NaN
# 2             2704.0     5.954828  1.002207     0.071111        NaN       NaN
#
# [3 rows x 22 columns]

# %%
residential_blocks.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0eb5bb5e262b32d3b9225bb48e744fc4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0eb5bb5e262b32d3b9225bb48e744fc4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0eb5bb5e262b32d3b9225bb48e744fc4 = L.map(
#                 &quot;map_0eb5bb5e262b32d3b9225bb48e744fc4&quot;,
#                 {
#                     center: [59.94953054899284, 30.48125270745949],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_0eb5bb5e262b32d3b9225bb48e744fc4);
#
#
#
#
#
#             var tile_layer_275498a24ae2b09d34863eb128ae449d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_275498a24ae2b09d34863eb128ae449d.addTo(map_0eb5bb5e262b32d3b9225bb48e744fc4);
#
#
#             map_0eb5bb5e262b32d3b9225bb48e744fc4.fitBounds(
#                 [[59.9450635667831, 30.471979900760804], [59.95399753120258, 30.490525514158172]],
#                 {}
#             );
#
#
#         function geo_json_9359c2fd6bcbdd8a59f11a3cd4996671_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_9359c2fd6bcbdd8a59f11a3cd4996671_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_9359c2fd6bcbdd8a59f11a3cd4996671_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_9359c2fd6bcbdd8a59f11a3cd4996671_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_9359c2fd6bcbdd8a59f11a3cd4996671_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_9359c2fd6bcbdd8a59f11a3cd4996671.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_9359c2fd6bcbdd8a59f11a3cd4996671_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_9359c2fd6bcbdd8a59f11a3cd4996671 = L.geoJson(null, {
#                 onEachFeature: geo_json_9359c2fd6bcbdd8a59f11a3cd4996671_onEachFeature,
#
#                 style: geo_json_9359c2fd6bcbdd8a59f11a3cd4996671_styler,
#                 pointToLayer: geo_json_9359c2fd6bcbdd8a59f11a3cd4996671_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_9359c2fd6bcbdd8a59f11a3cd4996671_add (data) {
#             geo_json_9359c2fd6bcbdd8a59f11a3cd4996671
#                 .addData(data);
#         }
#             geo_json_9359c2fd6bcbdd8a59f11a3cd4996671_add({&quot;bbox&quot;: [30.471979900760804, 59.9450635667831, 30.490525514158172, 59.95399753120258], &quot;features&quot;: [{&quot;bbox&quot;: [30.475727408093263, 59.9450635667831, 30.484382074061536, 59.94914462164647], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.475727408093263, 59.947652544997005], [30.478320571976035, 59.9450635667831], [30.484382074061536, 59.94519971804831], [30.484381989992663, 59.94600453581521], [30.4813

# %% [markdown]
# В max_rectangle_finder происходит процесс вписывания прямоугольников в полигоны кварталов с целью закрыть большую часть квартала ими. У прямоугольников есть нижний порог по стороне. Этот шаг нужен для нормализации застройки до сетчатой и имитации серий строительства.
#
# Пока что наиболее затратный по времени этап.

# %%
segments = max_rectangle_finder.pack_inscribed_rectangles_for_gdf(
    residential_blocks,
    step= generation_parameters.rectangle_finder_step,
    min_side= generation_parameters.minimal_rectangle_side,
    n_jobs= generation_parameters.jobs_number,
)
segments.head(3)
# Out:
# Packing rectangles (parallel):   0%|          | 0/3 [00:00<?, ?it/s]
#                                             geometry  width  height      area  \
# 0  POLYGON ((359317.117 6648412.513, 359003.165 6...  320.0   345.0  110400.0
# 1  POLYGON ((359450.824 6648119.036, 359273.373 6...   65.0   195.0   12675.0
# 2  POLYGON ((359458.334 6648048.282, 359385.534 6...   40.0    80.0    3200.0
#
#         angle  src_index  rect_id
# 0  114.493937          0        0
# 1  114.493937          0        1
# 2  114.493937          0        2

# %% [markdown]
# Далее building_need и building_capacity пересчитывается для сегментов.

# %%
(
    residential_blocks,
    segments,
) = segments_allocator.update_blocks_with_segments(
    residential_blocks,
    segments,
    far=density_scenario,
)
segments.head(3)
# Out:
#                                             geometry  width  height      area  \
# 0  POLYGON ((359317.117 6648412.513, 359003.165 6...  320.0   345.0  110400.0
# 1  POLYGON ((359450.824 6648119.036, 359273.373 6...   65.0   195.0   12675.0
# 2  POLYGON ((359458.334 6648048.282, 359385.534 6...   40.0    80.0    3200.0
#
#         angle  src_index  rect_id  plots_capacity  plot_front  plot_depth  \
# 0  114.493937          0        0               2       120.0        50.0
# 1  114.493937          0        1               1       120.0        50.0
# 2  114.493937          0        2               0       120.0         NaN
#
#      la_target  far_initial  building_length  building_width  floors_count  \
# 0  2385.906444          0.4             40.0            12.0           5.0
# 1  2385.906444          0.4             40.0            12.0           5.0
# 2  2385.906444          0.4             40.0            12.0           5.0
#
#   floors_group
# 0       medium
# 1       medium
# 2       medium

# %%
segments.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2cbad1b36d9e0e97a793be2d75792e24 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2cbad1b36d9e0e97a793be2d75792e24&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2cbad1b36d9e0e97a793be2d75792e24 = L.map(
#                 &quot;map_2cbad1b36d9e0e97a793be2d75792e24&quot;,
#                 {
#                     center: [59.94951687442178, 30.48125113288829],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_2cbad1b36d9e0e97a793be2d75792e24);
#
#
#
#
#
#             var tile_layer_c2055baaae5dd37e11ed98d9f51251a1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c2055baaae5dd37e11ed98d9f51251a1.addTo(map_2cbad1b36d9e0e97a793be2d75792e24);
#
#
#             map_2cbad1b36d9e0e97a793be2d75792e24.fitBounds(
#                 [[59.94507706227114, 30.472110663750296], [59.953956686572425, 30.49039160202628]],
#                 {}
#             );
#
#
#         function geo_json_6f7e6af2bd03969aaf66ed9a427799dc_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_6f7e6af2bd03969aaf66ed9a427799dc_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_6f7e6af2bd03969aaf66ed9a427799dc_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_6f7e6af2bd03969aaf66ed9a427799dc_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_6f7e6af2bd03969aaf66ed9a427799dc_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_6f7e6af2bd03969aaf66ed9a427799dc.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_6f7e6af2bd03969aaf66ed9a427799dc_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_6f7e6af2bd03969aaf66ed9a427799dc = L.geoJson(null, {
#                 onEachFeature: geo_json_6f7e6af2bd03969aaf66ed9a427799dc_onEachFeature,
#
#                 style: geo_json_6f7e6af2bd03969aaf66ed9a427799dc_styler,
#                 pointToLayer: geo_json_6f7e6af2bd03969aaf66ed9a427799dc_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_6f7e6af2bd03969aaf66ed9a427799dc_add (data) {
#             geo_json_6f7e6af2bd03969aaf66ed9a427799dc
#                 .addData(data);
#         }
#             geo_json_6f7e6af2bd03969aaf66ed9a427799dc_add({&quot;bbox&quot;: [30.472110663750296, 59.94507706227114, 30.49039160202628, 59.953956686572425], &quot;features&quot;: [{&quot;bbox&quot;: [30.475743844962235, 59.94507706227114, 30.483831475516368, 59.94903440805384], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.48126076825572, 59.94903440805384], [30.475743844962235, 59.947643933428445], [30.478314865722556, 59.94507706227114], [30.483831475516368, 59.94646742781417], [30.4

# %% [markdown]
# В сегменты вписываются кварталы: от краев сегментов строятся 4 полосы глубиной, равной глубине участка plot_depth. Затем квадраты пересечений на углах сливаются по длинной стороне сегментов. Эти полосы делятся по ширине участков plot_side. Если в процессе образуются слишком узкие участки, они сливаются с соседними.
#
# После создания участков параметры зданий пересчитываются для соответствия таргету по жилой площади и плотности.

# %%
plots = plots_generator.generate_plots(segments)
plots.head(3)
# Out:
#    width  height      area       angle  src_index  rect_id  plots_capacity  \
# 2  415.0   265.0  109975.0  110.458382          2        0              10
# 3   70.0   110.0    7700.0  110.458382          2        2               2
# 4   70.0   110.0    7700.0  110.458382          2        2               2
#
#    plot_front  plot_depth    la_target  ...  segment_side  \
# 2        40.0        22.5  2698.045172  ...     corner_br
# 3        40.0        22.5  2698.045172  ...     corner_br
# 4        40.0        22.5  2698.045172  ...     corner_tr
#
#                                             geometry  plot_area  \
# 2  POLYGON ((359643.469 6648459.097, 359622.388 6...     506.25
# 3  POLYGON ((359796.423 6648070.552, 359775.342 6...     506.25
# 4  POLYGON ((359693.361 6648032.104, 359685.497 6...     506.25
#
#    living_per_building living_area total_living_area   la_diff  la_ratio  \
# 2                 41.6        41.6            2694.9 -3.145172  0.998834
# 3                 41.6        41.6            2694.9 -3.145172  0.998834
# 4                 41.6        41.6            2694.9 -3.145172  0.998834
#
#    far_final  far_diff
# 2   0.058355 -0.012756
# 3   0.058355 -0.012756
# 4   0.058355 -0.012756
#
# [3 rows x 26 columns]

# %%
plots.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22b453a973634e8c0ac67ce7c1e34c53 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22b453a973634e8c0ac67ce7c1e34c53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_22b453a973634e8c0ac67ce7c1e34c53 = L.map(
#                 &quot;map_22b453a973634e8c0ac67ce7c1e34c53&quot;,
#                 {
#                     center: [59.949516874421775, 30.481251132888282],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_22b453a973634e8c0ac67ce7c1e34c53);
#
#
#
#
#
#             var tile_layer_9b566fc84fd51587970547f09799a5cc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b566fc84fd51587970547f09799a5cc.addTo(map_22b453a973634e8c0ac67ce7c1e34c53);
#
#
#             map_22b453a973634e8c0ac67ce7c1e34c53.fitBounds(
#                 [[59.945077062271125, 30.472110663750286], [59.953956686572425, 30.49039160202628]],
#                 {}
#             );
#
#
#         function geo_json_6e228a685a877b2ae487d73324d058fa_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_6e228a685a877b2ae487d73324d058fa_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_6e228a685a877b2ae487d73324d058fa_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_6e228a685a877b2ae487d73324d058fa_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_6e228a685a877b2ae487d73324d058fa_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_6e228a685a877b2ae487d73324d058fa.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_6e228a685a877b2ae487d73324d058fa_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_6e228a685a877b2ae487d73324d058fa = L.geoJson(null, {
#                 onEachFeature: geo_json_6e228a685a877b2ae487d73324d058fa_onEachFeature,
#
#                 style: geo_json_6e228a685a877b2ae487d73324d058fa_styler,
#                 pointToLayer: geo_json_6e228a685a877b2ae487d73324d058fa_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_6e228a685a877b2ae487d73324d058fa_add (data) {
#             geo_json_6e228a685a877b2ae487d73324d058fa
#                 .addData(data);
#         }
#             geo_json_6e228a685a877b2ae487d73324d058fa_add({&quot;bbox&quot;: [30.472110663750286, 59.945077062271125, 30.49039160202628, 59.953956686572425], &quot;features&quot;: [{&quot;bbox&quot;: [30.486538823522334, 59.94948591023895, 30.487065455879357, 59.94975007304302], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.487065455879357, 59.94956364339051], [30.486693792861146, 59.94948591023895], [30.486538823522334, 59.949672339445776], [30.486910488243275, 59.94975007304302],

# %% [markdown]
# В участки вписываются полигоны зданий с итоговыми параметрами длины, ширины и высоты, начиная от середины квартала. Гарантируется отступ в 3 метра от границ участка.

# %%
buildings_gdf = residential_buildings_generator.generate_buildings_from_plots(plots)
buildings_gdf.head(3)
# Out:
#                                             geometry  building_length  \
# 0  POLYGON ((359634.142 6648463.356, 359631.346 6...              8.0
# 1  POLYGON ((359787.096 6648074.811, 359784.3 664...              8.0
# 2  POLYGON ((359705.115 6648044.227, 359702.319 6...              8.0
#
#    building_width  floors_count  living_area  src_index
# 0             8.0           1.0         41.6          2
# 1             8.0           1.0         41.6          2
# 2             8.0           1.0         41.6          2

# %%
buildings_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54390c5c97bb73f1d5d06d696e90ffc4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54390c5c97bb73f1d5d06d696e90ffc4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54390c5c97bb73f1d5d06d696e90ffc4 = L.map(
#                 &quot;map_54390c5c97bb73f1d5d06d696e90ffc4&quot;,
#                 {
#                     center: [59.949489899537625, 30.481440655607155],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_54390c5c97bb73f1d5d06d696e90ffc4);
#
#
#
#
#
#             var tile_layer_a635671d484f418dcfb656ecc7b5952f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a635671d484f418dcfb656ecc7b5952f.addTo(map_54390c5c97bb73f1d5d06d696e90ffc4);
#
#
#             map_54390c5c97bb73f1d5d06d696e90ffc4.fitBounds(
#                 [[59.945360458351246, 30.472803900758603], [59.953619340724, 30.490077410455708]],
#                 {}
#             );
#
#
#         function geo_json_219e2c74be941c4c534dd42a21fe792d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_219e2c74be941c4c534dd42a21fe792d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_219e2c74be941c4c534dd42a21fe792d_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_219e2c74be941c4c534dd42a21fe792d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_219e2c74be941c4c534dd42a21fe792d_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_219e2c74be941c4c534dd42a21fe792d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_219e2c74be941c4c534dd42a21fe792d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_219e2c74be941c4c534dd42a21fe792d = L.geoJson(null, {
#                 onEachFeature: geo_json_219e2c74be941c4c534dd42a21fe792d_onEachFeature,
#
#                 style: geo_json_219e2c74be941c4c534dd42a21fe792d_styler,
#                 pointToLayer: geo_json_219e2c74be941c4c534dd42a21fe792d_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_219e2c74be941c4c534dd42a21fe792d_add (data) {
#             geo_json_219e2c74be941c4c534dd42a21fe792d
#                 .addData(data);
#         }
#             geo_json_219e2c74be941c4c534dd42a21fe792d_add({&quot;bbox&quot;: [30.472803900758603, 59.945360458351246, 30.490077410455708, 59.953619340724], &quot;features&quot;: [{&quot;bbox&quot;: [30.486708516542574, 59.949571029402215, 30.486895763602853, 59.949664953954766], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.486895763602853, 59.94959866790716], [30.486840663803832, 59.949664953954766], [30.486708516542574, 59.949637315393474], [30.486763616556853, 59.949571029402215],

# %% [markdown]
# Далее мы получаем нормативы по сервисам вида Х мест на 1000 человек из urban_db. Они уникальны для каждой территории.
#
# На основе этих нормативов и суммы распределенной жилой площади для каждого квартала определяются лимиты для сервисов (требуемая вместимость). В пространстве кварталов, не занятых участками жилых зданий, алгоритм старается разместить участки сервисов (параметры участков и зданий сервисов находятся в service_projects.geojson), пока весь лимит вместимости не будет покрыт, либо пока не закончится место. Для каждого сервиса есть несколько проектов разной вместимости и площади участков, алгоритм отдает приоритет закрытию лимитов большими зданиями.

# %%
territory_id = 1
service_normatives = await urban_db_api.get_normatives_for_territory(territory_id)
residential_services = residential_service_generator.generate_services(residential_blocks, plots, 
                                                                buildings_gdf, service_normatives, 32636)

# %%
residential_services.head(3)
# Out:
#    src_index      service           project_id  capacity  floors_count  \
# 0          0  Поликлиника  polyclinic_kazan_20     400.0             5
# 1          0  Детский сад     kindergarten_140     140.0             2
# 2          1  Поликлиника  polyclinic_kazan_20     400.0             5
#
#                                            osm_url  \
# 0  https://www.openstreetmap.org/relation/18102614
# 1       https://www.openstreetmap.org/way/28202955
# 2  https://www.openstreetmap.org/relation/18102614
#
#                                              address  \
# 0  23, улица Академика Сахарова, Азино-1, Советск...
# 1  11 к2, улица Коллонтай, Klochki, Невский округ...
# 2  23, улица Академика Сахарова, Азино-1, Советск...
#
#                                             geometry
# 0  POLYGON ((359195.887 6648205.977, 359213.927 6...
# 1  POLYGON ((359135.037 6648236.582, 359110.29 66...
# 2  POLYGON ((359340.493 6648671.509, 359363.387 6...

# %%
residential_services.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_afd3fc54e819d80795286452e215c638 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_afd3fc54e819d80795286452e215c638&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_afd3fc54e819d80795286452e215c638 = L.map(
#                 &quot;map_afd3fc54e819d80795286452e215c638&quot;,
#                 {
#                     center: [59.94936718119305, 30.48201672404815],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_afd3fc54e819d80795286452e215c638);
#
#
#
#
#
#             var tile_layer_be0ac0f9a003d25c2b9c158e55e86246 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be0ac0f9a003d25c2b9c158e55e86246.addTo(map_afd3fc54e819d80795286452e215c638);
#
#
#             map_afd3fc54e819d80795286452e215c638.fitBounds(
#                 [[59.946745850539244, 30.477159159724046], [59.95198851184685, 30.486874288372253]],
#                 {}
#             );
#
#
#         function geo_json_bc475ca0bde0d50187026348fd1ca476_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_bc475ca0bde0d50187026348fd1ca476_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_bc475ca0bde0d50187026348fd1ca476_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_bc475ca0bde0d50187026348fd1ca476_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_bc475ca0bde0d50187026348fd1ca476_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_bc475ca0bde0d50187026348fd1ca476.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_bc475ca0bde0d50187026348fd1ca476_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_bc475ca0bde0d50187026348fd1ca476 = L.geoJson(null, {
#                 onEachFeature: geo_json_bc475ca0bde0d50187026348fd1ca476_onEachFeature,
#
#                 style: geo_json_bc475ca0bde0d50187026348fd1ca476_styler,
#                 pointToLayer: geo_json_bc475ca0bde0d50187026348fd1ca476_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_bc475ca0bde0d50187026348fd1ca476_add (data) {
#             geo_json_bc475ca0bde0d50187026348fd1ca476
#                 .addData(data);
#         }
#             geo_json_bc475ca0bde0d50187026348fd1ca476_add({&quot;bbox&quot;: [30.477159159724046, 59.946745850539244, 30.486874288372253, 59.95198851184685], &quot;features&quot;: [{&quot;bbox&quot;: [30.479233514300997, 59.946745850539244, 30.480471216495623, 59.94736490628188], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.479233514300997, 59.947140222898184], [30.479571871858028, 59.94693894358483], [30.479896434916256, 59.946745850539244], [30.480471216495623, 59.94698897394137],

# %% [markdown]
# Далее жилые здания и здания сервисов объединяются в общий gdf и передаются на фронт.

# %%
result  = pd.concat([buildings_gdf, residential_services])
result.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94e38b8728b4fa094a92d0f40c5febdd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94e38b8728b4fa094a92d0f40c5febdd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94e38b8728b4fa094a92d0f40c5febdd = L.map(
#                 &quot;map_94e38b8728b4fa094a92d0f40c5febdd&quot;,
#                 {
#                     center: [59.949489899537625, 30.481440655607155],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_94e38b8728b4fa094a92d0f40c5febdd);
#
#
#
#
#
#             var tile_layer_3db724e2bc0536978eff6fa9e0a5898a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3db724e2bc0536978eff6fa9e0a5898a.addTo(map_94e38b8728b4fa094a92d0f40c5febdd);
#
#
#             map_94e38b8728b4fa094a92d0f40c5febdd.fitBounds(
#                 [[59.945360458351246, 30.472803900758603], [59.953619340724, 30.490077410455708]],
#                 {}
#             );
#
#
#         function geo_json_1c08b15c4dcf19d9c4f3c331fd756a19_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_1c08b15c4dcf19d9c4f3c331fd756a19_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_1c08b15c4dcf19d9c4f3c331fd756a19_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_1c08b15c4dcf19d9c4f3c331fd756a19_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_1c08b15c4dcf19d9c4f3c331fd756a19_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_1c08b15c4dcf19d9c4f3c331fd756a19.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_1c08b15c4dcf19d9c4f3c331fd756a19_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_1c08b15c4dcf19d9c4f3c331fd756a19 = L.geoJson(null, {
#                 onEachFeature: geo_json_1c08b15c4dcf19d9c4f3c331fd756a19_onEachFeature,
#
#                 style: geo_json_1c08b15c4dcf19d9c4f3c331fd756a19_styler,
#                 pointToLayer: geo_json_1c08b15c4dcf19d9c4f3c331fd756a19_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_1c08b15c4dcf19d9c4f3c331fd756a19_add (data) {
#             geo_json_1c08b15c4dcf19d9c4f3c331fd756a19
#                 .addData(data);
#         }
#             geo_json_1c08b15c4dcf19d9c4f3c331fd756a19_add({&quot;bbox&quot;: [30.472803900758603, 59.945360458351246, 30.490077410455708, 59.953619340724], &quot;features&quot;: [{&quot;bbox&quot;: [30.486708516542574, 59.949571029402215, 30.486895763602853, 59.949664953954766], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.486895763602853, 59.94959866790716], [30.486840663803832, 59.949664953954766], [30.486708516542574, 59.949637315393474], [30.486763616556853, 59.949571029402215],
